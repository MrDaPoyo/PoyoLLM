# %%
import sys
sys.path.append('.')

# %%
from minbpe import BasicTokenizer

tokenizer = BasicTokenizer()
tokenizer.load(model_file="./output/tokenizer/poyo_tokenizer.model")


def get_vocab_size(tokenizer: BasicTokenizer) -> int:
    vocab = tokenizer.vocab
    special_tokens = tokenizer.special_tokens

    return len(vocab) + len(special_tokens)

# %%
import torch
from model import GPTLanguageModel

block_size = 1024
n_embd = 768
n_head = 12
n_layer = 1
dropout = 0.2
batch_size = 128
vocab_size = get_vocab_size(tokenizer)
device = 'cuda' if torch.cuda.is_available() else 'cpu'

model = GPTLanguageModel().to(device)
model = torch.compile(model)

print(sum(p.numel() for p in model.parameters())/1e6, 'M parameters')
# Out:
# 22.467336 M parameters

# %%
with open("./output/single_string.txt", "r") as f:
    text_sequence = f.read()

encoded_text_sequence = tokenizer.encode(text_sequence)
len(encoded_text_sequence)
# Out:
# 135235

# %% [markdown]
# # Splitting between training data and testing data

# %%
data = torch.tensor(encoded_text_sequence, dtype=torch.long)
split_index = int(0.9*len(data))
train_data = data[:split_index]
val_data = data[split_index:]

# %%
from typing import Tuple


def get_batch(split: str) -> Tuple[torch.Tensor, torch.Tensor]:
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    index = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in index])
    y = torch.stack([data[i+1:i+block_size+1] for i in index])
    x, y = x.to(device), y.to(device)
    return x, y

# %%
x, y = get_batch('train')
x.shape, y.shape
# Out:
# (torch.Size([128, 1024]), torch.Size([128, 1024]))

# %% [markdown]
# # TRAINING HECK YEAH

# %%
from typing import Dict
import torch._dynamo
torch._dynamo.config.suppress_errors = True

eval_iters = 200


@torch.no_grad()
def estimate_loss() -> Dict:
    output = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            x, y = get_batch(split)
            _, loss = model(x, y)
            losses[k] = loss.item()
        output[split] = losses.mean()
    model.train()
    return output

# %%
def save_checkpoint(
    model: GPTLanguageModel,
    optimizer: torch.optim.Optimizer,
    epoch: int,
    loss: float,
    file_path: str = "checkpoint.pth"
) -> None:
    checkpoint = {
        'epoch': epoch,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'loss': loss
    }
    torch.save(checkpoint, file_path)
    torch.cuda.empty_cache()

# %%
max_iters = 1000
eval_interval = 10
learning_rate = 1e-4
save_interval = 100
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

train_losses = []
val_losses = []

for iteration in range(max_iters):
    if iteration % eval_interval == 0 or iteration == max_iters - 1:
        losses = estimate_loss()
        print(
            f"step {iteration}: "
            f"train loss {losses['train']:.4f}, "
            f"val loss {losses['val']:.4f}"
        )
        train_losses.append(losses['train'])
        val_losses.append(losses['val'])

    x_batch, y_batch = get_batch('train')
    logits, loss = model(x_batch, y_batch)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

    if iteration % save_interval == 0:
        save_checkpoint(
            model=model,
            optimizer=optimizer,
            epoch=iteration,
            loss=loss.item(),
            file_path=f"./output/pre_training/run_1/checkpoint_{iteration}.pth"
        )
# Out:
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233] WON'T CONVERT forward c:\Users\CEX\code\PoyoLLM\model.py line 151
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233] due to:
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233] Traceback (most recent call last):
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_dynamo\convert_frame.py", line 1164, in __call__
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     result = self._inner_convert(
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]              ^^^^^^^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_dynamo\convert_frame.py", line 547, in __call__
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     return _compile(
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]            ^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_dynamo\convert_frame.py", line 986, in _compile
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     guarded_code = compile_inner(code, one_graph, hooks, transform)
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_dynamo\convert_frame.py", line 715, in compile_inner
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     return _compile_inner(code, one_graph, hooks, transform)
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_utils_internal.py", line 95, in wrapper_function
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     return function(*args, **kwargs)
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_dynamo\convert_frame.py", line 750, in _compile_inner
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     out_code = transform_code_object(code, transform)
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_dynamo\bytecode_transformation.py", line 1361, in transform_code_object
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     transformations(instructions, code_options)
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_dynamo\convert_frame.py", line 231, in _fn
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     return fn(*args, **kwargs)
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_dynamo\convert_frame.py", line 662, in transform
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     tracer.run()
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2868, in run
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     super().run()
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 1052, in run
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     while self.step():
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]           ^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 962, in step
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     self.dispatch_table[inst.opcode](self, inst)
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 3048, in RETURN_VALUE
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     self._return(inst)
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 3033, in _return
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     self.output.compile_subgraph(
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_dynamo\output_graph.py", line 1136, in compile_subgraph
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     self.compile_and_call_fx_graph(
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_dynamo\output_graph.py", line 1382, in compile_and_call_fx_graph
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     compiled_fn = self.call_user_compiler(gm)
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_dynamo\output_graph.py", line 1432, in call_user_compiler
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     return self._call_user_compiler(gm)
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_dynamo\output_graph.py", line 1483, in _call_user_compiler
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     raise BackendCompilerFailed(self.compiler_fn, e).with_traceback(
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_dynamo\output_graph.py", line 1462, in _call_user_compiler
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     compiled_fn = compiler_fn(gm, self.example_inputs())
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_dynamo\repro\after_dynamo.py", line 130, in __call__
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     compiled_gm = compiler_fn(gm, example_inputs)
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\__init__.py", line 2340, in __call__
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     return compile_fx(model_, inputs_, config_patches=self.config)
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_inductor\compile_fx.py", line 1863, in compile_fx
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     return aot_autograd(
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]            ^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_dynamo\backends\common.py", line 83, in __call__
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     cg = aot_module_simplified(gm, example_inputs, **self.kwargs)
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_functorch\aot_autograd.py", line 1155, in aot_module_simplified
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     compiled_fn = dispatch_and_compile()
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]                   ^^^^^^^^^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_functorch\aot_autograd.py", line 1131, in dispatch_and_compile
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     compiled_fn, _ = create_aot_dispatcher_function(
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_functorch\aot_autograd.py", line 580, in create_aot_dispatcher_function
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     return _create_aot_dispatcher_function(
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_functorch\aot_autograd.py", line 830, in _create_aot_dispatcher_function
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     compiled_fn, fw_metadata = compiler_fn(
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]                                ^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_functorch\_aot_autograd\jit_compile_runtime_wrappers.py", line 203, in aot_dispatch_base
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     compiled_fw = compiler(fw_module, updated_flat_args)
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_functorch\aot_autograd.py", line 489, in __call__
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     return self.compiler_fn(gm, example_inputs)
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_inductor\compile_fx.py", line 1741, in fw_compiler_base
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     return inner_compile(
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]            ^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_inductor\compile_fx.py", line 569, in compile_fx_inner
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     return wrap_compiler_debug(_compile_fx_inner, compiler_name="inductor")(
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_dynamo\repro\after_aot.py", line 102, in debug_wrapper
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     inner_compiled_fn = compiler_fn(gm, example_inputs)
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_inductor\compile_fx.py", line 685, in _compile_fx_inner
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     mb_compiled_graph = fx_codegen_and_compile(
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]                         ^^^^^^^^^^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_inductor\compile_fx.py", line 1129, in fx_codegen_and_compile
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     return scheme.codegen_and_compile(gm, example_inputs, inputs_to_check, graph_kwargs)
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_inductor\compile_fx.py", line 1044, in codegen_and_compile
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     compiled_fn = graph.compile_to_module().call
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]                   ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_inductor\graph.py", line 2027, in compile_to_module
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     return self._compile_to_module()
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_inductor\graph.py", line 2033, in _compile_to_module
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     self.codegen_with_cpp_wrapper() if self.cpp_wrapper else self.codegen()
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]                                                              ^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_inductor\graph.py", line 1968, in codegen
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     self.scheduler.codegen()
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_inductor\scheduler.py", line 3477, in codegen
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     return self._codegen()
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]            ^^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_inductor\scheduler.py", line 3554, in _codegen
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     self.get_backend(device).codegen_node(node)
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_inductor\codegen\cpp.py", line 4777, in codegen_node
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     self.codegen_outer_loop_node(node)
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_inductor\codegen\cpp.py", line 4751, in codegen_outer_loop_node
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     if not try_outer_loop_fusion_with_local_buf(node):
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_inductor\codegen\cpp.py", line 4726, in try_outer_loop_fusion_with_local_buf
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     cpp_kernel_proxy = CppKernelProxy(kernel_group)
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_inductor\codegen\cpp.py", line 3632, in __init__
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     self.picked_vec_isa: cpu_vec_isa.VecISA = cpu_vec_isa.pick_vec_isa()
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]                                               ^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_inductor\cpu_vec_isa.py", line 414, in pick_vec_isa
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     _valid_vec_isa_list: List[VecISA] = valid_vec_isa_list()
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]                                         ^^^^^^^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_inductor\cpu_vec_isa.py", line 401, in valid_vec_isa_list
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     isa_list.extend(
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_inductor\cpu_vec_isa.py", line 404, in <genexpr>
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     if all(flag in _cpu_supported_x86_isa for flag in str(isa).split()) and isa
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]                                                                             ^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_inductor\cpu_vec_isa.py", line 142, in __bool__
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     return self.__bool__impl(config.cpp.vec_isa_ok)
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_inductor\cpu_vec_isa.py", line 152, in __bool__impl
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     return self.check_build(VecISA._avx_code)
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_inductor\cpu_vec_isa.py", line 102, in check_build
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     extra=_get_isa_dry_compile_fingerprint(self._arch_flags),
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_inductor\cpu_vec_isa.py", line 28, in _get_isa_dry_compile_fingerprint
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     compiler_info = get_compiler_version_info(get_cpp_compiler())
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]                                               ^^^^^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_inductor\cpp_builder.py", line 144, in get_cpp_compiler
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     check_compiler_exist_windows(compiler)
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_inductor\cpp_builder.py", line 135, in check_compiler_exist_windows
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     raise RuntimeError(f"Compiler: {compiler} is not found.") from exc
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233] RuntimeError: Compiler: cl is not found.
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233] Traceback (most recent call last):
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_dynamo\convert_frame.py", line 1164, in __call__
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     result = self._inner_convert(
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]              ^^^^^^^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_dynamo\convert_frame.py", line 547, in __call__
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     return _compile(
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]            ^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_dynamo\convert_frame.py", line 986, in _compile
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     guarded_code = compile_inner(code, one_graph, hooks, transform)
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_dynamo\convert_frame.py", line 715, in compile_inner
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     return _compile_inner(code, one_graph, hooks, transform)
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_utils_internal.py", line 95, in wrapper_function
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     return function(*args, **kwargs)
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_dynamo\convert_frame.py", line 750, in _compile_inner
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     out_code = transform_code_object(code, transform)
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_dynamo\bytecode_transformation.py", line 1361, in transform_code_object
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     transformations(instructions, code_options)
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_dynamo\convert_frame.py", line 231, in _fn
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     return fn(*args, **kwargs)
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_dynamo\convert_frame.py", line 662, in transform
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     tracer.run()
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2868, in run
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     super().run()
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 1052, in run
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     while self.step():
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]           ^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 962, in step
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     self.dispatch_table[inst.opcode](self, inst)
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 3048, in RETURN_VALUE
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     self._return(inst)
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 3033, in _return
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     self.output.compile_subgraph(
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_dynamo\output_graph.py", line 1136, in compile_subgraph
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     self.compile_and_call_fx_graph(
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_dynamo\output_graph.py", line 1382, in compile_and_call_fx_graph
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     compiled_fn = self.call_user_compiler(gm)
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_dynamo\output_graph.py", line 1432, in call_user_compiler
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     return self._call_user_compiler(gm)
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_dynamo\output_graph.py", line 1483, in _call_user_compiler
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     raise BackendCompilerFailed(self.compiler_fn, e).with_traceback(
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_dynamo\output_graph.py", line 1462, in _call_user_compiler
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     compiled_fn = compiler_fn(gm, self.example_inputs())
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_dynamo\repro\after_dynamo.py", line 130, in __call__
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     compiled_gm = compiler_fn(gm, example_inputs)
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\__init__.py", line 2340, in __call__
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     return compile_fx(model_, inputs_, config_patches=self.config)
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_inductor\compile_fx.py", line 1863, in compile_fx
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     return aot_autograd(
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]            ^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_dynamo\backends\common.py", line 83, in __call__
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     cg = aot_module_simplified(gm, example_inputs, **self.kwargs)
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_functorch\aot_autograd.py", line 1155, in aot_module_simplified
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     compiled_fn = dispatch_and_compile()
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]                   ^^^^^^^^^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_functorch\aot_autograd.py", line 1131, in dispatch_and_compile
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     compiled_fn, _ = create_aot_dispatcher_function(
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_functorch\aot_autograd.py", line 580, in create_aot_dispatcher_function
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     return _create_aot_dispatcher_function(
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_functorch\aot_autograd.py", line 830, in _create_aot_dispatcher_function
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     compiled_fn, fw_metadata = compiler_fn(
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]                                ^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_functorch\_aot_autograd\jit_compile_runtime_wrappers.py", line 203, in aot_dispatch_base
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     compiled_fw = compiler(fw_module, updated_flat_args)
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_functorch\aot_autograd.py", line 489, in __call__
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     return self.compiler_fn(gm, example_inputs)
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_inductor\compile_fx.py", line 1741, in fw_compiler_base
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     return inner_compile(
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]            ^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_inductor\compile_fx.py", line 569, in compile_fx_inner
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     return wrap_compiler_debug(_compile_fx_inner, compiler_name="inductor")(
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_dynamo\repro\after_aot.py", line 102, in debug_wrapper
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     inner_compiled_fn = compiler_fn(gm, example_inputs)
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_inductor\compile_fx.py", line 685, in _compile_fx_inner
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     mb_compiled_graph = fx_codegen_and_compile(
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]                         ^^^^^^^^^^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_inductor\compile_fx.py", line 1129, in fx_codegen_and_compile
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     return scheme.codegen_and_compile(gm, example_inputs, inputs_to_check, graph_kwargs)
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_inductor\compile_fx.py", line 1044, in codegen_and_compile
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     compiled_fn = graph.compile_to_module().call
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]                   ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_inductor\graph.py", line 2027, in compile_to_module
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     return self._compile_to_module()
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_inductor\graph.py", line 2033, in _compile_to_module
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     self.codegen_with_cpp_wrapper() if self.cpp_wrapper else self.codegen()
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]                                                              ^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_inductor\graph.py", line 1968, in codegen
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     self.scheduler.codegen()
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_inductor\scheduler.py", line 3477, in codegen
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     return self._codegen()
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]            ^^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_inductor\scheduler.py", line 3554, in _codegen
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     self.get_backend(device).codegen_node(node)
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_inductor\codegen\cpp.py", line 4777, in codegen_node
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     self.codegen_outer_loop_node(node)
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_inductor\codegen\cpp.py", line 4751, in codegen_outer_loop_node
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     if not try_outer_loop_fusion_with_local_buf(node):
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_inductor\codegen\cpp.py", line 4726, in try_outer_loop_fusion_with_local_buf
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     cpp_kernel_proxy = CppKernelProxy(kernel_group)
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_inductor\codegen\cpp.py", line 3632, in __init__
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     self.picked_vec_isa: cpu_vec_isa.VecISA = cpu_vec_isa.pick_vec_isa()
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]                                               ^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_inductor\cpu_vec_isa.py", line 414, in pick_vec_isa
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     _valid_vec_isa_list: List[VecISA] = valid_vec_isa_list()
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]                                         ^^^^^^^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_inductor\cpu_vec_isa.py", line 401, in valid_vec_isa_list
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     isa_list.extend(
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_inductor\cpu_vec_isa.py", line 404, in <genexpr>
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     if all(flag in _cpu_supported_x86_isa for flag in str(isa).split()) and isa
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]                                                                             ^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_inductor\cpu_vec_isa.py", line 142, in __bool__
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     return self.__bool__impl(config.cpp.vec_isa_ok)
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_inductor\cpu_vec_isa.py", line 152, in __bool__impl
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     return self.check_build(VecISA._avx_code)
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_inductor\cpu_vec_isa.py", line 102, in check_build
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     extra=_get_isa_dry_compile_fingerprint(self._arch_flags),
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_inductor\cpu_vec_isa.py", line 28, in _get_isa_dry_compile_fingerprint
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     compiler_info = get_compiler_version_info(get_cpp_compiler())
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]                                               ^^^^^^^^^^^^^^^^^^
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_inductor\cpp_builder.py", line 144, in get_cpp_compiler
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     check_compiler_exist_windows(compiler)
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_inductor\cpp_builder.py", line 135, in check_compiler_exist_windows
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     raise RuntimeError(f"Compiler: {compiler} is not found.") from exc
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233] RuntimeError: Compiler: cl is not found.
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# W0422 22:56:34.048000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]
# W0422 22:56:37.486000 17500 site-packages\torch\_dynamo\convert_frame.py:1233] WON'T CONVERT forward c:\Users\CEX\code\PoyoLLM\model.py line 119
# W0422 22:56:37.486000 17500 site-packages\torch\_dynamo\convert_frame.py:1233] due to:
# W0422 22:56:37.486000 17500 site-packages\torch\_dynamo\convert_frame.py:1233] Traceback (most recent call last):
# W0422 22:56:37.486000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_dynamo\convert_frame.py", line 1164, in __call__
# W0422 22:56:37.486000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     result = self._inner_convert(
# W0422 22:56:37.486000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]              ^^^^^^^^^^^^^^^^^^^^
# W0422 22:56:37.486000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_dynamo\convert_frame.py", line 547, in __call__
# W0422 22:56:37.486000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     return _compile(
# W0422 22:56:37.486000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]            ^^^^^^^^^
# W0422 22:56:37.486000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_dynamo\convert_frame.py", line 986, in _compile
# W0422 22:56:37.486000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     guarded_code = compile_inner(code, one_graph, hooks, transform)
# W0422 22:56:37.486000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0422 22:56:37.486000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_dynamo\convert_frame.py", line 715, in compile_inner
# W0422 22:56:37.486000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     return _compile_inner(code, one_graph, hooks, transform)
# W0422 22:56:37.486000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0422 22:56:37.486000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_utils_internal.py", line 95, in wrapper_function
# W0422 22:56:37.486000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     return function(*args, **kwargs)
# ...
# W0422 22:56:50.302000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     self.scheduler.codegen()
# W0422 22:56:50.302000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_inductor\scheduler.py", line 3477, in codegen
# W0422 22:56:50.302000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     return self._codegen()
# W0422 22:56:50.302000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]            ^^^^^^^^^^^^^^^
# W0422 22:56:50.302000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_inductor\scheduler.py", line 3554, in _codegen
# W0422 22:56:50.302000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     self.get_backend(device).codegen_node(node)
# W0422 22:56:50.302000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_inductor\codegen\cpp.py", line 4781, in codegen_node
# W0422 22:56:50.302000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     cpp_kernel_proxy = CppKernelProxy(kernel_group)
# W0422 22:56:50.302000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0422 22:56:50.302000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_inductor\codegen\cpp.py", line 3632, in __init__
# W0422 22:56:50.302000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     self.picked_vec_isa: cpu_vec_isa.VecISA = cpu_vec_isa.pick_vec_isa()
# W0422 22:56:50.302000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]                                               ^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0422 22:56:50.302000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_inductor\cpu_vec_isa.py", line 414, in pick_vec_isa
# W0422 22:56:50.302000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     _valid_vec_isa_list: List[VecISA] = valid_vec_isa_list()
# W0422 22:56:50.302000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]                                         ^^^^^^^^^^^^^^^^^^^^
# W0422 22:56:50.302000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_inductor\cpu_vec_isa.py", line 401, in valid_vec_isa_list
# W0422 22:56:50.302000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     isa_list.extend(
# W0422 22:56:50.302000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_inductor\cpu_vec_isa.py", line 404, in <genexpr>
# W0422 22:56:50.302000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     if all(flag in _cpu_supported_x86_isa for flag in str(isa).split()) and isa
# W0422 22:56:50.302000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]                                                                             ^^^
# W0422 22:56:50.302000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_inductor\cpu_vec_isa.py", line 142, in __bool__
# W0422 22:56:50.302000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     return self.__bool__impl(config.cpp.vec_isa_ok)
# W0422 22:56:50.302000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0422 22:56:50.302000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_inductor\cpu_vec_isa.py", line 152, in __bool__impl
# W0422 22:56:50.302000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     return self.check_build(VecISA._avx_code)
# W0422 22:56:50.302000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0422 22:56:50.302000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_inductor\cpu_vec_isa.py", line 102, in check_build
# W0422 22:56:50.302000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     extra=_get_isa_dry_compile_fingerprint(self._arch_flags),
# W0422 22:56:50.302000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0422 22:56:50.302000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_inductor\cpu_vec_isa.py", line 28, in _get_isa_dry_compile_fingerprint
# W0422 22:56:50.302000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     compiler_info = get_compiler_version_info(get_cpp_compiler())
# W0422 22:56:50.302000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]                                               ^^^^^^^^^^^^^^^^^^
# W0422 22:56:50.302000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_inductor\cpp_builder.py", line 144, in get_cpp_compiler
# W0422 22:56:50.302000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     check_compiler_exist_windows(compiler)
# W0422 22:56:50.302000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]   File "c:\Users\CEX\miniconda3\Lib\site-packages\torch\_inductor\cpp_builder.py", line 135, in check_compiler_exist_windows
# W0422 22:56:50.302000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]     raise RuntimeError(f"Compiler: {compiler} is not found.") from exc
# W0422 22:56:50.302000 17500 site-packages\torch\_dynamo\convert_frame.py:1233] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# W0422 22:56:50.302000 17500 site-packages\torch\_dynamo\convert_frame.py:1233] RuntimeError: Compiler: cl is not found.
# W0422 22:56:50.302000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]
# W0422 22:56:50.302000 17500 site-packages\torch\_dynamo\convert_frame.py:1233] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# W0422 22:56:50.302000 17500 site-packages\torch\_dynamo\convert_frame.py:1233]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 12
#      10 for iteration in range(max_iters):
#      11     if iteration % eval_interval == 0 or iteration == max_iters - 1:
# ---> 12         losses = estimate_loss()
#      13         print(
#      14             f"step {iteration}: "
#      15             f"train loss {losses['train']:.4f}, "
#      16             f"val loss {losses['val']:.4f}"
#      17         )
#      18         train_losses.append(losses['train'])
#
# File c:\Users\CEX\miniconda3\Lib\site-packages\torch\utils\_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# Cell In[23], line 16, in estimate_loss()
#      14 for k in range(eval_iters):
#      15     x, y = get_batch(split)
# ---> 16     _, loss = model(x, y)
#      17     losses[k] = loss.item()
#      18 output[split] = losses.mean()
#
# File c:\Users\CEX\miniconda3\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File c:\Users\CEX\miniconda3\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File c:\Users\CEX\miniconda3\Lib\site-packages\torch\_dynamo\eval_frame.py:574, in _TorchDynamoContext.__call__.<locals>._fn(*args, **kwargs)
#     569 saved_dynamic_layer_stack_depth = (
#     570     torch._C._functorch.get_dynamic_layer_stack_depth()
#     571 )
#     573 try:
# --> 574     return fn(*args, **kwargs)
#     575 finally:
#     576     # Restore the dynamic layer stack depth if necessary.
#     577     torch._C._functorch.pop_dynamic_layer_stack_and_undo_to_depth(
#     578         saved_dynamic_layer_stack_depth
#     579     )
#
# File c:\Users\CEX\miniconda3\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File c:\Users\CEX\miniconda3\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File c:\Users\CEX\code\PoyoLLM\model.py:172, in forward(self, input_tokens, targets)
#     162 def forward(self, input_tokens: torch.Tensor, targets: Optional[torch.Tensor] = None) -> Tuple[torch.Tensor, Optional[torch.Tensor]]:
#     163     """
#     164     Forward pass of the model.
#     165
#     166     Args:
#     167         input_tokens: Tensor of token indices of shape (B, T)
#     168         targets: Optional tensor of target token indices of shape (B, T)
#     169
#     170     Returns:
#     171         Tuple of (logits, loss). Logits shape (B, T, vocab_size).
# --> 172         Loss is optional cross-entropy loss if targets are provided.
#     173     """
#     174     B, T = input_tokens.shape
#     176     # Get token and position embeddings
#
# File c:\Users\CEX\miniconda3\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File c:\Users\CEX\miniconda3\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File c:\Users\CEX\miniconda3\Lib\site-packages\torch\nn\modules\container.py:250, in Sequential.forward(self, input)
#     248 def forward(self, input):
#     249     for module in self:
# --> 250         input = module(input)
#     251     return input
#
# File c:\Users\CEX\miniconda3\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File c:\Users\CEX\miniconda3\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File c:\Users\CEX\code\PoyoLLM\model.py:121, in Block.forward(self, x)
#     119 def forward(self, x: torch.Tensor) -> torch.Tensor:
#     120     # Residual connection around self-attention
# --> 121     x = x + self.self_attention(self.layer_norm_1(x))
#     122     # Residual connection around feed-forward
#     123     x = x + self.feed_forward(self.layer_norm_2(x))
#
# File c:\Users\CEX\miniconda3\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File c:\Users\CEX\miniconda3\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File c:\Users\CEX\code\PoyoLLM\model.py:88, in MultiHeadAttention.forward(self, x)
#      86 def forward(self, x: torch.Tensor) -> torch.Tensor:
#      87     # Concatenate heads' outputs along the feature dimension
# ---> 88     out = torch.cat([h(x) for h in self.heads], dim=-1) # (B, T, num_heads * head_size)
#      89     out = self.dropout(self.projection(out)) # (B, T, N_EMBD)
#      90     return out
#
# File c:\Users\CEX\miniconda3\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File c:\Users\CEX\miniconda3\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File c:\Users\CEX\code\PoyoLLM\model.py:68, in forward(self, x)
#      66 weights = weights.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
#      67 weights = F.softmax(weights, dim=-1) # (B, T, T)
# ---> 68 weights = self.dropout(weights)
#      70 # Perform the weighted aggregation of the values
#      71 v = self.value(x) # (B, T, head_size)
#
# File c:\Users\CEX\miniconda3\Lib\site-packages\torch\nn\modules\module.py:1915, in Module.__getattr__(self, name)
#    1910         self._backward_pre_hooks = OrderedDict()
#    1912 # It is crucial that the return type is not annotated as `Any`, otherwise type checking
#    1913 # on `torch.nn.Module` and all its subclasses is largely disabled as a result. See:
#    1914 # https://github.com/pytorch/pytorch/pull/115074
# -> 1915 def __getattr__(self, name: str) -> Union[Tensor, "Module"]:
#    1916     if "_parameters" in self.__dict__:
#    1917         _parameters = self.__dict__["_parameters"]
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.plot(train_losses, label="Train Loss")
plt.plot(val_losses, label="Validation Loss")
plt.xlabel("Evaluation Step")
plt.ylim(0)
plt.ylabel("Loss")
plt.title("Training and Validation Loss Over Time")
plt.legend()
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 import matplotlib.pyplot as plt
#       3 plt.figure(figsize=(10, 5))
# ----> 4 plt.plot(train_losses, label="Train Loss")
#       5 plt.plot(val_losses, label="Validation Loss")
#       6 plt.xlabel("Evaluation Step")
#
# NameError: name 'train_losses' is not defined
